# %% [markdown]
# # Final Report — Spring 2026
#
# ## CISC 339: Artificial Intelligence
#
# ---
#
# ## Materials
#
# **Part I — Industry Perspective**
# Watch the NVIDIA GTC 2026 keynote by Jensen Huang (CEO, NVIDIA):
# 🎬 [https://www.youtube.com/watch?v=jw_o0xr8MWU](https://www.youtube.com/watch?v=jw_o0xr8MWU)
#
# **Part II — Research Perspective**
# Read the **Top Takeaways** section (pages 9–11) of the Stanford AI Index Report 2026:
# 📄 Provided on Blackboard: `ai_index_report_2026.pdf`
# Full report (optional deeper reading): [https://aiindex.stanford.edu/report/](https://aiindex.stanford.edu/report/)
#
# ---
#
# ## Requirements
#
# - Answer each question in **3–5 sentences**.
# - Write your answers in the cells marked with `#` below each question.
# - Responses must reflect the **actual content** of the video/report — do not rely solely on outside sources or AI summaries.
# - Part III questions require your **own reasoned judgment** — there is no single correct answer, but you must support your position with specific evidence from the materials.
# - Academic integrity applies: do not submit AI-generated answers verbatim.
#
# ---

# %% [markdown]
# ## Part I — GTC 2026: The Industry View
#
# *NVIDIA GTC (GPU Technology Conference) is the premier annual AI industry event. The keynote is delivered by Jensen Huang, NVIDIA's CEO and co-founder. NVIDIA's GPUs power the majority of AI model training and inference worldwide.*

# %% [markdown]
# **Q1.** Jensen Huang argues that we have entered a new era of **"physical AI"** — AI that interacts with and acts in the physical world. How does he define physical AI, and why does he consider this moment as significant as the original ChatGPT breakthrough in 2022? What examples does he give?

# %%
# Q1 Answer:

# %% [markdown]
# **Q2.** NVIDIA announced the **Vera Rubin** platform as the successor to Blackwell. What specific problem or bottleneck does each new GPU generation aim to address? According to Jensen, why will demand for computing power continue to grow rather than plateau once models become "good enough"?

# %%
# Q2 Answer:

# %% [markdown]
# **Q3.** Autonomous vehicles were central to the keynote, with partnerships announced with major global automakers. Jensen describes the robotaxi not just as a self-driving car but as **"a new computing platform."** What does he mean by this distinction, and what does it imply about NVIDIA's business strategy beyond selling GPUs?

# %%
# Q3 Answer:

# %% [markdown]
# **Q4.** The keynote emphasizes **agentic AI** — AI systems that can plan, take actions, and operate autonomously over time — as the next major frontier. How does an AI *agent* differ from the chatbot-style AI you used in earlier labs? Describe a concrete use case from the keynote that illustrates this difference.

# %%
# Q4 Answer:

# %% [markdown]
# **Q5.** Jensen projects over **$1 trillion** in AI computing demand through 2027. What reasoning or trends does he use to justify this figure? Does the keynote provide data to support it, or is it primarily a forward-looking vision? How do you evaluate the claim?

# %%
# Q5 Answer:

# %% [markdown]
# **Q6.** Jensen Huang is both a technology visionary and the CEO of a company whose revenue depends on continued AI investment. How might his role shape the narrative presented in the keynote? What perspectives, risks, or counterarguments are **absent** from his presentation that you think should have been included?

# %%
# Q6 Answer:

# %% [markdown]
# ---
# ## Part II — Stanford AI Index 2026: The Data View
#
# *The Stanford AI Index is an annual report produced by the Stanford Institute for Human-Centered AI (HAI) — an independent academic institution. It aggregates data from governments, research labs, industry, and surveys to provide a comprehensive, evidence-based picture of where AI stands globally. Read the **Top Takeaways** section (pages 9–11) before answering.*

# %% [markdown]
# **Q7.** The report introduces the concept of the **"jagged frontier"** of AI capability. Define this term in your own words and illustrate it with one specific example from the report. Why does this concept matter when evaluating confident claims about what AI can or cannot do?

# %%
# Q7 Answer:

# %% [markdown]
# **Q8.** Stanford reports a striking divide: **73% of AI experts** expect AI to have a positive impact on how people do their jobs, compared to only **23% of the general public** — a 50-point gap. What factors might explain this divide? Which group do you think has a more accurate picture of reality, and why?

# %%
# Q8 Answer:

# %% [markdown]
# **Q9.** The report documents **productivity gains of 14–26%** in fields like software development and customer support — yet employment among young software developers (ages 22–25) has fallen nearly **20%**. How do you reconcile these two findings? What does this tell us about the relationship between AI-driven productivity and job availability?

# %%
# Q9 Answer:

# %% [markdown]
# **Q10.** Despite leading the world in AI private investment ($285.9 billion in 2025), the United States ranks **24th globally in generative AI adoption** at only 28.3%. Countries like Singapore (61%) and the UAE (54%) rank far higher. What might explain this gap between investment leadership and consumer adoption?

# %%
# Q10 Answer:

# %% [markdown]
# **Q11.** The number of AI researchers and developers moving to the United States has dropped **89% since 2017**, with 80% of that decline occurring in just the last year. The report treats this as a risk to U.S. AI leadership. Do you agree? What are the broader implications — for the U.S., for other countries, and for the global AI ecosystem?

# %%
# Q11 Answer:

# %% [markdown]
# **Q12.** Industry now produces **over 90% of notable AI models**, and frontier labs are increasingly withholding training details — parameters, dataset sizes, training code. Why does scientific transparency matter in AI development? Who benefits from less transparency, and who is harmed?

# %%
# Q12 Answer:

# %% [markdown]
# ---
# ## Part III — Synthesis & Critical Thinking
#
# *These questions have no single correct answer. You are expected to take a position and defend it with specific evidence from the two materials above.*

# %% [markdown]
# **Q13.** GTC 2026 presents AI as an unstoppable technological wave driving trillion-dollar demand and transforming every industry. The Stanford AI Index presents a more nuanced picture: rapid capability growth alongside uneven adoption, emerging labor disruption, and widening governance gaps. Which narrative do you find **more useful** for understanding where AI actually stands today? Support your answer with specific evidence from both sources.

# %%
# Q13 Answer:

# %% [markdown]
# **Q14.** Jensen Huang said that **"the ChatGPT moment of self-driving cars has arrived."** Using the Stanford report's concept of the jagged frontier and the documented gap between AI capability and real-world deployment, critically evaluate this claim. Is it a well-supported statement, strategic marketing, or something in between? What evidence would you need to see to fully believe it?

# %%
# Q14 Answer:

# %% [markdown]
# **Q15.** Stanford reports that **4 in 5 university students** now use generative AI for schoolwork. You are one of them. Reflect on your own use of AI during this course: How has it changed how you approach learning, problem-solving, or assignments? Do you think AI makes you a better learner, a more dependent one, or both — and does it matter?

# %%
# Q15 Answer:

# %% [markdown]
# **Q16.** You have now completed a semester studying AI — from search algorithms to neural networks to large language models. Looking at the two materials together: what is the **single most important thing** you think a non-technical person should understand about AI right now? And what is one thing you personally plan to do differently because of what you learned this semester?

# %%
# Q16 Answer:

# %% [markdown]
# ---
# *CISC 339 — Artificial Intelligence · Spring 2026*
