# %% [markdown]
# # Final Report
#
# <img src="https://raw.githubusercontent.com/tisage/CISC339/refs/heads/main/Projects/nvidia-gtc-logo.jpg"/>
#
#
# The Nvidia GPU Technology Conference (GTC) is a premier global event for artificial intelligence (AI) professionals. It gathers developers, engineers, researchers, innovators, and IT experts to discuss cutting-edge advancements in AI, machine learning, computer graphics, data science, and autonomous systems.
#
# For your final project, please watch the keynote presentation available at: [https://www.youtube.com/watch?v=lQHK61IDFH4](https://www.youtube.com/watch?v=lQHK61IDFH4) by Nvidia's CEO and Founder, Jensen Huang and answer the following questions.
#
# Requirement:
# - Answer each question concisely in 2-3 sentences.
# - Provide your answers directly in the designated cells following the # comment for each question.
# - Format your responses with proper line breaks for better readability, avoiding long, continuous lines of text.
#
# Since 2024
#
# v. 1.2
#
# ---

# %% [markdown]
# ## I. The New Computing Paradigm and Acceleration
#
# **Q1: The CEO describes AI as a "new industrial revolution" and "essential infrastructure." How does this perception fundamentally shift the role of computing in society, according to the sources?**

# %%
#

# %% [markdown]
# **Q2: What technological constraint led NVIDIA to advance the computing model known as "accelerated computing," and how does this model fundamentally differ from traditional computing?**

# %%
#

# %% [markdown]
# **Q3: Describe the role of 'tokens' in the context of the AI factory, and explain how tokenization expands AI's applicability beyond traditional language models like chatbots.**

# %%
#

# %% [markdown]
# ## II. AI Architecture and Scaling
# **Q4: Explain the three fundamental technology skills or "scaling laws" that have made AI much smarter and led to an extraordinary increase in computational load.**

# %%
#

# %% [markdown]
# **Q5: What is the "virtuous cycle" of AI that the video describes, and what two exponential demands are driving the current pressure on computational resources?**

# %%
#

# %% [markdown]
# **Q6: What is "extreme co-design," and how does it allow the Grace Blackwell NVLink72 system to achieve 10 times the performance compared to previous generations?**

# %%
#

# %% [markdown]
# **Q7: How does the Grace Blackwell architecture address the cost challenges associated with exponential AI growth, and what business visibility does NVIDIA have as a result of this technology?**

# %%
#

# %% [markdown]
# ## III. Quantum and Wireless Innovations
# **Q8: What is NVQLink, and why is it considered essential for the future of quantum computing?**

# %%
#

# %% [markdown]
# **Q9: What is NVIDIA Arc, and what are the two main ways AI will be used on the Radio Access Network (RAN) to advance 6G?**

# %%
#

# %% [markdown]
# ## IV. AI Applications and Partnerships
# **Q10: The video highlights several strategic enterprise partnerships. Describe the role of AI in the newly announced partnerships with CrowdStrike and Palantir.**

# %%
#

# %% [markdown]
# **Q11: Explain the three distinct computing systems required for Physical AI, as discussed in the keynote.**

# %%
#

# %% [markdown]
# **Q12: What is NVIDIA Omniverse DSX, and what role does the digital twin play in its implementation for gigascale AI factories?**

# %%
#

# %% [markdown]
# **Q13: Why does NVIDIA emphasize its dedication to open-source models, despite also having proprietary models?**

# %%
#

# %% [markdown]
# **Q14: How is the concept of a "robotaxi" being standardized and deployed as a new computing platform, and which major ride-sharing partner was announced?**

# %%
#

# %% [markdown]
# **Q15. What was your favorite part of the keynote presentation, and why?****

# %%
#
